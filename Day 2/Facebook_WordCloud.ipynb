# %%
from bs4 import BeautifulSoup

with open('your_posts_1.html',encoding="utf8"
) as page:
  soup = BeautifulSoup(page, 'html.parser')

# %%
soup
# Out:
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><base href="../"/><style nonce="vP02O0VO" type="text/css">html{touch-action:manipulation}body{background:#fff;color:#1c1e21;direction:ltr;line-height:1.34;margin:0;padding:0;unicode-bidi:embed}body,button,input,label,select,td,textarea{font-family:Helvetica, Arial, sans-serif;font-size:12px}h1,h2,h3,h4,h5,h6{color:#1c1e21;font-size:13px;font-weight:600;margin:0;padding:0}h1{font-size:14px}h4,h5,h6{font-size:12px}p{margin:1em 0}b,strong{font-weight:600}a{color:#385898;cursor:pointer;text-decoration:none}button{margin:0}a:hover{text-decoration:underline}img{border:0}td,td.label{text-align:left}dd{color:#000}dt{color:#606770}ul{list-style-type:none;margin:0;padding:0}abbr{border-bottom:none;text-decoration:none}hr{background:#dadde1;border-width:0;color:#dadde1;height:1px}form{margin:0;padding:0}label{color:#606770;cursor:default;font-weight:600;vertical-align:middle}label input{font-weight:normal}textarea,.
# ...

# %%
contents = soup.find_all('div', class_ = '_2pin')

# %%
contents
# Out:
# [<div class="_2pin"><div><div><table cellpadding="0" cellspacing="0" class="uiGrid _51mz"><tbody><tr class="_51mx"><td class="_51m- pas"><div><a href="photos_and_videos/TimelinePhotos_T1pxmEBsfg/152947664_466757291121111_8402832644544987411_o_466757284454445.jpg"><img class="_2yuc _3-96" src="photos_and_videos/TimelinePhotos_T1pxmEBsfg/152947664_466757291121111_8402832644544987411_o_466757284454445.jpg"/></a><div class="_3-95">Just ended my classes with @[1405090646463166:274:Shopee] Code League Singapore.
#
#  Excited with the projects that will result from this! Good luck to all contestants! 😊
#
#  P.S. I hope we can have a strong Filipino corpus soon. 🙏</div></div></td></tr></tbody></table></div></div></div>,
#  <div class="_2pin"><div>Just ended my classes with Shopee Code League Singapore.<br/> <br/> Excited with the projects that will result from this! Good luck to all contestants! 😊<br/> <br/> P.S. I hope we can have a strong Filipino corpus soon. 🙏</div><div></div></div>,
# ...

# %%
[i.get_text() for i in contents]
# Out:
# ['Just ended my classes with @[1405090646463166:274:Shopee] Code League Singapore.\n\nExcited with the projects that will result from this! Good luck to all contestants! 😊\n\nP.S. I hope we can have a strong Filipino corpus soon. 🙏',
#  'Just ended my classes with Shopee Code League Singapore.  Excited with the projects that will result from this! Good luck to all contestants! 😊  P.S. I hope we can have a strong Filipino corpus soon. 🙏',
#  'Technology is political.\n\nIn order for us to create technology that is holistic and considerate to our social consciousness, we need to discuss and engage social problems. \n\n#NeverForget\n#NeverAgain\n#NoToRedTagging\n#JunkTerrorLaw\n#EDSA35\n#ResistTyranny',
#  'Technology is political.  In order for us to create technology that is holistic and considerate to our social consciousness, we need to discuss and engage social problems.   #NeverForget #NeverAgain #NoToRedTagging #JunkTerrorLaw #EDSA35 #ResistTyranny',
# ...

# %%
x = []
for i in contents:
  x.append(i.get_text())

# %%
x
# Out:
# ['Just ended my classes with @[1405090646463166:274:Shopee] Code League Singapore.\n\nExcited with the projects that will result from this! Good luck to all contestants! 😊\n\nP.S. I hope we can have a strong Filipino corpus soon. 🙏',
#  'Just ended my classes with Shopee Code League Singapore.  Excited with the projects that will result from this! Good luck to all contestants! 😊  P.S. I hope we can have a strong Filipino corpus soon. 🙏',
#  'Technology is political.\n\nIn order for us to create technology that is holistic and considerate to our social consciousness, we need to discuss and engage social problems. \n\n#NeverForget\n#NeverAgain\n#NoToRedTagging\n#JunkTerrorLaw\n#EDSA35\n#ResistTyranny',
#  'Technology is political.  In order for us to create technology that is holistic and considerate to our social consciousness, we need to discuss and engage social problems.   #NeverForget #NeverAgain #NoToRedTagging #JunkTerrorLaw #EDSA35 #ResistTyranny',
# ...

# %%
y = ' '.join(x)

# %%
y
# Out:
# 'Just ended my classes with @[1405090646463166:274:Shopee] Code League Singapore.\n\nExcited with the projects that will result from this! Good luck to all contestants! 😊\n\nP.S. I hope we can have a strong Filipino corpus soon. 🙏 Just ended my classes with Shopee Code League Singapore.  Excited with the projects that will result from this! Good luck to all contestants! 😊  P.S. I hope we can have a strong Filipino corpus soon. 🙏 Technology is political.\n\nIn order for us to create technology that is holistic and considerate to our social consciousness, we need to discuss and engage social problems. \n\n#NeverForget\n#NeverAgain\n#NoToRedTagging\n#JunkTerrorLaw\n#EDSA35\n#ResistTyranny Technology is political.  In order for us to create technology that is holistic and considerate to our social consciousness, we need to discuss and engage social problems.   #NeverForget #NeverAgain #NoToRedTagging #JunkTerrorLaw #EDSA35 #ResistTyranny Had a blast with my first Natural Language Process
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import random 

def grey_color_func(word, font_size, position,
                   orientation, random_state = None,
                   **kwargs):
  return "hsl(0, 0$$, %d%%)" % random.randint(60,100)

from PIL import Image
import numpy as np

mask = np.array(Image.open('a.png')) # Where to get this file

wordcloud = WordCloud(background_color='white',
                      max_words=2000,width = 1024,
                      height = 720,
                      mask = mask)

wordcloud.generate(y)

plt.figure(figsize = (20,8))
plt.title('Facebook Wordcloud')
plt.imshow(wordcloud.recolor(color_func=grey_color_func, 
                             random_state = 3), 
                             interpolation =  'bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-9c0fb3b973d3> in <module>
#      11 import numpy as np
#      12
# ---> 13 mask = np.array()
#      14
#      15 wordcloud = WordCloud(background_color='white',
#
# TypeError: array() missing required argument 'object' (pos 1)
